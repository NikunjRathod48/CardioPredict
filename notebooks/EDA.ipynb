# %% [markdown]
# ### 1. Import Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Read Dataset File

# %%
dataFrame = pd.read_csv('../dataset/cardio_train.csv', sep=';')
dataFrame
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %% [markdown]
# ### 3. Numbers Of Rows & Columns

# %%
print(f"Rows : {dataFrame.shape[0]}")
print(f"Columns : {dataFrame.shape[1]}")
# Out:
# Rows : 70000
# Columns : 13

# %% [markdown]
# ### 4. Basic Info Of Dataset

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %% [markdown]
# ### 5. Summary Statistics

# %%
dataFrame.describe().T
# Out:
#                count          mean           std      min       25%      50%  \
# id           70000.0  49972.419900  28851.302323      0.0  25006.75  50001.5
# age          70000.0  19468.865814   2467.251667  10798.0  17664.00  19703.0
# gender       70000.0      1.349571      0.476838      1.0      1.00      1.0
# height       70000.0    164.359229      8.210126     55.0    159.00    165.0
# weight       70000.0     74.205690     14.395757     10.0     65.00     72.0
# ap_hi        70000.0    128.817286    154.011419   -150.0    120.00    120.0
# ap_lo        70000.0     96.630414    188.472530    -70.0     80.00     80.0
# cholesterol  70000.0      1.366871      0.680250      1.0      1.00      1.0
# gluc         70000.0      1.226457      0.572270      1.0      1.00      1.0
# smoke        70000.0      0.088129      0.283484      0.0      0.00      0.0
# alco         70000.0      0.053771      0.225568      0.0      0.00      0.0
# ...

# %% [markdown]
# ### 6. List Of All Columns

# %%
dataFrame.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
for col in dataFrame.columns:
    print(f"\nColumn: {col}")
    print(dataFrame[col].nunique())
    print(dataFrame[col].unique())
# Out:
# Column: id
# 70000
# [    0     1     2 ... 99996 99998 99999]
#
# Column: age
# 8076
# [18393 20228 18857 ... 14925 17727 17926]
#
# Column: gender
# 2
# [2 1]
#
# Column: height
# 109
# [168 156 165 169 151 157 178 158 164 173 181 172 170 154 162 163 153 159
#  166 155 160 175 171 152 187 148 179 180 188 185 167 183 174 176 161 184
#  177 182  76 149 142 150 144 147 186 146 141 195 140 198 145 143 196 138
#  194 190 134 136 100 120 189 137 192 122 250 191 117  70  97 119 130 110
#  193  75 132  71 135  67 125 139 133  74  98 112 207  68  55  81  80  64
#   91  60 109  72 197  65 128 105 108 200 104 111 113  96 131  59  66  99
#   57]
#
# Column: weight
# 287
# [ 62.    85.    64.    82.    56.    67.    93.    95.    71.    68.
#   80.    60.    78.   112.    75.    52.    83.    69.    90.    45.
#   65.    59.    66.    74.   105.    73.    55.    70.    72.    63.
#   50.   107.    84.    77.    79.    76.    58.   115.    97.    53.
# ...

# %% [markdown]
# ### 7. Target Column Identification

# %%
dataFrame.cardio.value_counts()
# Out:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64

# %% [markdown]
# ### 8. Count Duplicate Recoords

# %%
print(dataFrame.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### 9. Missing Value Count

# %%
dataFrame.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %% [markdown]
# ### 10. Converting Age Column Values(Days) Into Years.

# %%
dataFrame['age_years'] = (dataFrame["age"] / 365).round(1).astype(float)
# dataFrame.to_csv("cardio_train_updated.csv", index=False) For Permanent Column In Dataset
dataFrame
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
# ...

# %% [markdown]
# ### 11. Add BMI column (BMI = weight / (height/100)^2)

# %%
dataFrame['BMI'] = dataFrame['weight'] / ((dataFrame['height']/100)**2)
dataFrame[['height','weight','BMI']]
# Out:
#        height  weight        BMI
# 0         168    62.0  21.967120
# 1         156    85.0  34.927679
# 2         165    64.0  23.507805
# 3         169    82.0  28.710479
# 4         156    56.0  23.011177
# ...       ...     ...        ...
# 69995     168    76.0  26.927438
# 69996     158   126.0  50.472681
# 69997     183   105.0  31.353579
# 69998     163    72.0  27.099251
# 69999     170    72.0  24.913495
#
# [70000 rows x 3 columns]

# %% [markdown]
# ### 11. Correlation Heatmap

# %%
corr_matrix = dataFrame.corr(numeric_only=True)
plt.figure(figsize=(20, 12))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### 13. Histogram For Height & Weight

# %%
plt.figure(figsize=(8, 4))
sns.histplot(data=dataFrame, x='weight', kde=True, color='orange')
plt.title("Distribution Of Weight")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(data=dataFrame, x='height', kde=True, color='orange')
plt.title("Distribution Of Height")
plt.show()

# %% [markdown]
# ### 14. Scatter Plot Of age_years vs ap_hi & ap_lo

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(x='age_years', y='ap_hi', hue='cardio', data=dataFrame.sample(min(70000, len(dataFrame))))
plt.title("age_years vs ap_hi")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(x='age_years', y='ap_lo', hue='cardio', data=dataFrame.sample(min(70000, len(dataFrame))))
plt.title("age_years vs ap_lo")
plt.show()

# %% [markdown]
# ### 15. BoxPlot For Height & Weight By Cardio

# %%
plt.figure(figsize=(9, 6))
sns.boxplot(x='cardio', y='height', data=dataFrame)
plt.title("Height By Cardio")
plt.show()

# %%
plt.figure(figsize=(9, 6))
sns.boxplot(x='cardio', y='weight', data=dataFrame)
plt.title("Weight By Cardio")
plt.show()

# %% [markdown]
# ### 16. Average Age Of Patient With Cardiovascular Disease

# %%
cardiovascular_disease = dataFrame[dataFrame['cardio'] == 1]
avg_age = cardiovascular_disease['age_years'].mean()
print(f"Average Age Of Patients With Cardiovascular Disease : {avg_age: .2f} Years")
# Out:
# Average Age Of Patients With Cardiovascular Disease :  54.95 Years

# %% [markdown]
# ### 17. Distribution of Cardiovascular Disease Cases by Gender and Cholesterol Level

# %%
dataFrame_Copy = dataFrame.copy()
dataFrame_Copy['Gender'] = dataFrame_Copy['gender'].map({1:'Women', 2: 'Men'})
dataFrame_Copy['Cholesterol'] = dataFrame_Copy['cholesterol'].map({1:'Normal', 2: 'Above Normal', 3: 'Well Above Normal'})
dataFrame_Copy.pivot_table(values='cardio', index='Gender', columns='Cholesterol', aggfunc='sum', fill_value=0)
# Out:
# Cholesterol  Above Normal  Normal  Well Above Normal
# Gender
# Men                  2006    8467               1890
# Women                3744   14588               4284

# %% [markdown]
# ### 18. Bar Plot For Cardiovascular Cases by Glucose Level

# %%
gluc_group = dataFrame.groupby('gluc')['cardio'].sum()
gluc_map = {1 :'Normal', 2: 'Above Normal', 3: 'Well Above Normal'}
gluc_group.index = gluc_group.index.map(gluc_map)

bars = gluc_group.plot(kind='barh')
plt.title("Cardiovascular Cases by Glucose Level")
plt.xlabel("Glucose Category")
plt.ylabel("Total Cardio Cases")

for bar in bars.patches:
    plt.text(bar.get_width() + 1, bar.get_y() + bar.get_height() / 2, bar.get_width())
    
plt.show()

# %% [markdown]
# ### 19. Average Height and Weight by Gender and Cardiovascular Disease Status

# %%
dataFrame_Copy['cardio_label'] = dataFrame_Copy['cardio'].map({1:'Cardiovascular Disease',0:'No Cardiovascular Disease'})
dataFrame_Copy.groupby(['Gender','cardio_label'])[['height','weight']].mean()
# Out:
#                                       height     weight
# Gender cardio_label
# Men    Cardiovascular Disease     170.070857  79.840929
#        No Cardiovascular Disease  169.822334  74.619055
# Women  Cardiovascular Disease     161.099487  75.172276
#        No Cardiovascular Disease  161.608405  69.992834

# %% [markdown]
# ### 20. Cardio Cases By Cholestrol & Glucose Levels

# %%
dataFrame_Copy['gluc_label'] = dataFrame_Copy['gluc'].map(gluc_map)
dataFrame_Copy.pivot_table(values='cardio', index='Cholesterol', columns='gluc_label', aggfunc='sum')
# Out:
# gluc_label         Above Normal  Normal  Well Above Normal
# Cholesterol
# Above Normal               1453    4068                229
# Normal                     1205   21168                682
# Well Above Normal           420    3349               2405

# %% [markdown]
# ### 21. Average BMI By Activity & Alcohol Consumption

# %%
dataFrame_Copy.groupby(['active', 'alco'])[['BMI']].mean()
# Out:
#                    BMI
# active alco
# 0      0     27.678899
#        1     28.946170
# 1      0     27.500084
#        1     27.738549

# %% [markdown]
# ### 22. Histogram Of Age Distribution(In Years)

# %%
plt.hist(dataFrame_Copy['age_years'], bins=30)
plt.title("Age Distribution")
plt.xlabel("Age (in Years)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### 23. Boxplot : Blood Pressure(ap_hi / ap_lo) by Cardio Status

# %%
sns.boxplot(x='cardio', y='ap_hi', data=dataFrame)
plt.title("Systolic BP Distribution By cardio Status")
plt.show()

# %%
sns.boxplot(x='cardio', y='ap_lo', data=dataFrame)
plt.title("Diastolic BP Distribution By cardio Status")
plt.show()

# %% [markdown]
# ### 24. Average Age(in Years) By Smoking & Cardio Status

# %%
dataFrame_Copy.pivot_table(values='age_years', index='smoke', columns='cardio_label', aggfunc='mean')
# Out:
# cardio_label  Cardiovascular Disease  No Cardiovascular Disease
# smoke
# 0                          55.057822                  51.807662
# 1                          53.771765                  50.976543

# %% [markdown]
# ### 24. Compare BP & BMI Across Activity levels & Gender For Disease VS Non-Disease Groups.

# %%
dataFrame_Copy.groupby(['Gender', 'active', 'cardio_label']).agg({
    'age_years': 'mean',
    'ap_hi' : 'mean',
    'ap_lo' : 'mean',
    'BMI' : 'mean'
}).round(2)
# Out:
#                                          age_years   ap_hi   ap_lo    BMI
# Gender active cardio_label
# Men    0      Cardiovascular Disease         54.58  133.50  100.26  27.77
#               No Cardiovascular Disease      51.51  120.74   97.12  26.17
#        1      Cardiovascular Disease         54.56  140.10  115.50  27.55
#               No Cardiovascular Disease      51.69  121.38   86.77  25.84
# Women  0      Cardiovascular Disease         55.28  136.03  102.22  29.13
#               No Cardiovascular Disease      51.76  121.96   82.07  26.93
#        1      Cardiovascular Disease         55.13  136.49  108.58  29.09
#               No Cardiovascular Disease      51.77  119.54   81.94  26.88
